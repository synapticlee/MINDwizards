# %%
import pandas as pd

# %%
pd.read_csv('wizard_gems_data_1cdzsxek92mz66k_2019-08-10.csv', 
             names=['trial_index','rt','gem_values','response', 'correct_answers', 'gem_weights'])
# Out:
#                                                                                                                                                                                                                                                                                                                                       trial_index  \
# rt    url                        experiment_phase trial_type               trial_index time_elapsed internal_node_id experiment_name workerId assignmentId hitId experiment_start_time experiment_end_time  total_time ip_address     version_date anon_id         demo_mode completion_code                page_rt gem_values           response
# ...
